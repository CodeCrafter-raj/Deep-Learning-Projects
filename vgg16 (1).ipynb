jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (45).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (3).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (142).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (139).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (429).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (90).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (431).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (309).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (232).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (490).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (335).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (75).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (137).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (247).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (394).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (141).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (192).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (229).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (361).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (131) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (74).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (92).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (167).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (374).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (177).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (230).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (179).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (8).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (263).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (327).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (28).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (245).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (481).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (383).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (153).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (181).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (457).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (420).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (23).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (226).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (500).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (128) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (478).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (84).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (105).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (14).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (100).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (314).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (132).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (2).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (127) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (293).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (303).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (126) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (66).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (19).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (223).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (51).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (236).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (222).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (140) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (136).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (278).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (1).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (218).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (233).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (487).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (6).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (315).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (307).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (174).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (317).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (241).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (377).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (485).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (129) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (76).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (7).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (471).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (130).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (430).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (112) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (111).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (115) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (95).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (496).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (175).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (13).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (224).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (55).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (389).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (109) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (257).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (189).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (447).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (125).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (127).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (143).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (8).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (465).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (237).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (392).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (188).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (3).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (318).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (80).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (475).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (89).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (141) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (119).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (215).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (2).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (118).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (472).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (473).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (375).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (139) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (109).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (308).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (140).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (456).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (446).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (365).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (435).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (176).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (210).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (120).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (462).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (467).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (43).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (113).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (379).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (217).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (486).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (360).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (1).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/desktop.ini
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (114).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (85).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (474).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (88).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (433).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (117).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (4).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (262).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (480).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (306).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (5).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (114) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (4).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (202).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (129).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (330).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (390).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (193).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (272).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (132) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (131).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (391).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (42).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (342).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (191).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (340).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (15).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (227).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (110) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (346).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (22).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (110).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (208).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (117) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (135) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (116).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (380).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (133).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (267).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (444).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (36).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (18).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (363).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (135).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (7).jpg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (178).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (170).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (464).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (256).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (79).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (209).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (198).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (479).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (258).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (366).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (120) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (321).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (302).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (125) - Copy.jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (78).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (266).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (183).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (228).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (497).jpeg
# /kaggle/input/herb300/train/Com_Purslanee/com_pursulanee (5).jpeg

# %%
import pathlib

# Assuming data_dir is the path to the directory containing subdirectories for each plant class
data_dir = pathlib.Path("/kaggle/input/herb300/train")

# Use glob to get a list of all subdirectories representing plant classes in data_dir
plant_classes = [subdir.name for subdir in data_dir.glob('*') if subdir.is_dir()]

# Initialize an empty dictionary
leaf_images_dict = {}

# Loop through each plant class and populate the dictionary
for plant_class in plant_classes:
    # Use the plant class name as the key and create a list of file paths using glob
    leaf_images_dict[plant_class] = list((data_dir / plant_class).glob('*'))

# Print the number of classes
print(f"Number of classes: {len(plant_classes)}")

# Print the number of images per class
for plant_class, file_paths in leaf_images_dict.items():
    print(f"{plant_class}: {len(file_paths)} images")
# Out:
# Number of classes: 43
# Pongamia_pinnata a: 301 images
# Alkanet_Root: 301 images
# Eclipta_Alba: 301 images
# Excoecaria cochinchinensiss: 301 images
# Solanum: 301 images
# Lonicera_caprifol: 301 images
# Prunella_vulgaris: 301 images
# Beefsteakk: 301 images
# Gotukola: 299 images
# Myrica esculentaa: 301 images
# leonarus: 301 images
# Kamarkas: 301 images
# Alpinia_Galangaa: 297 images
# Holarrhena antidysenterica: 301 images
# Andrographis paniculata: 301 images
# Chinese_Yumm: 301 images
# Lochnera_rosea: 301 images
# Lysimachia: 301 images
# Ramiee: 301 images
# Phyllanthuss: 301 images
# Abelmoschus_sagittifolius: 300 images
# Achyranthes_asperaa: 300 images
# Indian Bay Leaf: 301 images
# Gingerr: 301 images
# Abutilon_indicumm: 300 images
# Bearde_ iriss: 301 images
# Clerodendrum_serratumm: 301 images
# Oleander: 301 images
# Tulsii: 301 images
# Goumi_berries: 301 images
# Oriental: 301 images
# Artemisia_Argyii: 301 images
# Kumis: 301 images
# Schefflera heptaphylla: 301 images
# Rhodomyrtus: 301 images
# Basella_Albaa: 301 images
# Euphorbia: 301 images
# Tribulus terrestris: 301 images
# Rehmanniaa: 301 images
# Parijata: 301 images
# Adenosma glutinosumm: 300 images
# Eupatorium fortuneii: 301 images
# Com_Purslanee: 301 images

# %%
from PIL import Image
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow import keras 
from tensorflow.keras import layers
import PIL
import pathlib
from tensorflow.keras.models import Sequential
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras_tuner
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization,Embedding
from keras.layers import GlobalAveragePooling2D

# %%
def load_data_and_labels(directory_path):
    x, y = [], []

    subdirectories = [d for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]

    for class_index, subdir in enumerate(subdirectories):
        class_path = os.path.join(directory_path, subdir)

        for file_name in os.listdir(class_path):
            image_path = os.path.join(class_path, file_name)
            try:
                img = cv2.imread(image_path)
                if img is not None:
                    # Resize image to (32, 32)
                    resized_img = cv2.resize(img, (64, 64))
                    x.append(resized_img)
                    y.append(class_index)
                else:
                    print(f"Error: Unable to read the image {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")

    return np.array(x), np.array(y)

herbdata_path = '/kaggle/input/herb300/train'
x, y = load_data_and_labels(herbdata_path)

# Split the dataset into training, validation, and test sets
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Define ImageDataGenerator instances without augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators
batch_size = 64
num_classes = len(np.unique(y))
y_train_one_hot = to_categorical(y_train, num_classes=num_classes)
y_val_one_hot = to_categorical(y_val, num_classes=num_classes)
y_test_one_hot = to_categorical(y_test, num_classes=num_classes)

train_generator = train_datagen.flow(x_train, y_train_one_hot, batch_size=batch_size, shuffle=True)
val_generator = val_datagen.flow(x_val, y_val_one_hot, batch_size=batch_size, shuffle=False)
test_generator = test_datagen.flow(x_test, y_test_one_hot, batch_size=batch_size, shuffle=False)
# Out:
# Error: Unable to read the image /kaggle/input/herb300/train/Pongamia_pinnata a/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Alkanet_Root/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Eclipta_Alba/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Excoecaria cochinchinensiss/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Solanum/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lonicera_caprifol/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Prunella_vulgaris/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Beefsteakk/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Gotukola/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Myrica esculentaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/leonarus/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Kamarkas/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Alpinia_Galangaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Holarrhena antidysenterica/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Andrographis paniculata/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Chinese_Yumm/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lochnera_rosea/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lysimachia/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Ramiee/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Phyllanthuss/desktop.ini
# libpng warning: iTXt: CRC error
# libpng warning: iTXt: CRC error
# Error: Unable to read the image /kaggle/input/herb300/train/Indian Bay Leaf/desktop.ini
# libpng warning: iTXt: CRC error
# Corrupt JPEG data: 5 extraneous bytes before marker 0xee
# Error: Unable to read the image /kaggle/input/herb300/train/Gingerr/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Bearde_ iriss/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Clerodendrum_serratumm/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Oleander/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Tulsii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Goumi_berries/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Oriental/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Artemisia_Argyii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Kumis/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Schefflera heptaphylla/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Rhodomyrtus/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (6).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (5).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (2).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (4).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (3).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (1).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Euphorbia/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Tribulus terrestris/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Rehmanniaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Parijata/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Eupatorium fortuneii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Com_Purslanee/desktop.ini

# %%
print("Number of successfully read images:", len(x))
print("Number of corresponding labels:", len(y))
# Out:
# Number of successfully read images: 12888
# Number of corresponding labels: 12888

# %%
# Print the shapes of the resulting sets
print("Train set shapes:", x_train.shape, y_train.shape)
print("Validation set shapes:", x_val.shape, y_val.shape)
print("Test set shapes:", x_test.shape, y_test.shape)
# Out:
# Train set shapes: (9021, 64, 64, 3) (9021,)
# Validation set shapes: (1933, 64, 64, 3) (1933,)
# Test set shapes: (1934, 64, 64, 3) (1934,)

# %% [markdown]
# # model-1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, Dropout

img_shape = (64, 64, 3)
num_classes = 43

# Uncomment here 
Name = "VGG16"
classifier = VGG16(
    include_top=False,
    input_shape=img_shape,
    weights='imagenet'
)

fine_tune_at = 20
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

model = Sequential()
model.add(classifier)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# ... (previous code)

print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization (Batch  (None, 2048)              8192
#  Normalization)
#
#  dense (Dense)               (None, 128)               262272
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 14991211 (57.19 MB)
# Trainable params: 272171 (1.04 MB)
# Non-trainable params: 14719040 (56.15 MB)
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_Resnet.h5',
    monitor='val_accuracy',  # Change 'val_acc' to 'val_accuracy'
    mode='max',
    verbose=1
)


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Remove from_logits=True
    metrics=[
        'accuracy',
        tf.keras.metrics.CategoricalAccuracy(),
    ]
)


history = model.fit(train_generator, epochs=15, validation_data=val_generator, batch_size=batch_size)
# Out:
# Epoch 1/15
# 141/141 [==============================] - 8s 27ms/step - loss: 2.6163 - accuracy: 0.3389 - categorical_accuracy: 0.3389 - val_loss: 2.2250 - val_accuracy: 0.5054 - val_categorical_accuracy: 0.5054
# Epoch 2/15
# 141/141 [==============================] - 3s 21ms/step - loss: 1.4471 - accuracy: 0.6082 - categorical_accuracy: 0.6082 - val_loss: 1.4684 - val_accuracy: 0.6932 - val_categorical_accuracy: 0.6932
# Epoch 3/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.0393 - accuracy: 0.7195 - categorical_accuracy: 0.7195 - val_loss: 1.0492 - val_accuracy: 0.7791 - val_categorical_accuracy: 0.7791
# Epoch 4/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8063 - accuracy: 0.7842 - categorical_accuracy: 0.7842 - val_loss: 0.8726 - val_accuracy: 0.8210 - val_categorical_accuracy: 0.8210
# Epoch 5/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.6628 - accuracy: 0.8199 - categorical_accuracy: 0.8199 - val_loss: 0.7908 - val_accuracy: 0.8339 - val_categorical_accuracy: 0.8339
# Epoch 6/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.5409 - accuracy: 0.8550 - categorical_accuracy: 0.8550 - val_loss: 0.7677 - val_accuracy: 0.8541 - val_categorical_accuracy: 0.8541
# Epoch 7/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.4543 - accuracy: 0.8744 - categorical_accuracy: 0.8744 - val_loss: 0.7395 - val_accuracy: 0.8546 - val_categorical_accuracy: 0.8546
# Epoch 8/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.3885 - accuracy: 0.8919 - categorical_accuracy: 0.8919 - val_loss: 0.7856 - val_accuracy: 0.8614 - val_categorical_accuracy: 0.8614
# Epoch 9/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.3440 - accuracy: 0.9044 - categorical_accuracy: 0.9044 - val_loss: 0.7749 - val_accuracy: 0.8660 - val_categorical_accuracy: 0.8660
# Epoch 10/15
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3096 - accuracy: 0.9110 - categorical_accuracy: 0.9110 - val_loss: 0.7601 - val_accuracy: 0.8758 - val_categorical_accuracy: 0.8758
# Epoch 11/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2633 - accuracy: 0.9282 - categorical_accuracy: 0.9282 - val_loss: 0.7444 - val_accuracy: 0.8789 - val_categorical_accuracy: 0.8789
# Epoch 12/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2636 - accuracy: 0.9252 - categorical_accuracy: 0.9252 - val_loss: 0.7551 - val_accuracy: 0.8774 - val_categorical_accuracy: 0.8774
# Epoch 13/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2322 - accuracy: 0.9332 - categorical_accuracy: 0.9332 - val_loss: 0.7664 - val_accuracy: 0.8784 - val_categorical_accuracy: 0.8784
# Epoch 14/15
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2237 - accuracy: 0.9323 - categorical_accuracy: 0.9323 - val_loss: 0.7902 - val_accuracy: 0.8784 - val_categorical_accuracy: 0.8784
# Epoch 15/15
# 141/141 [==============================] - 3s 19ms/step - loss: 0.2090 - accuracy: 0.9398 - categorical_accuracy: 0.9398 - val_loss: 0.7652 - val_accuracy: 0.8779 - val_categorical_accuracy: 0.8779

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_Resnet.h6',
    monitor='val_accuracy',  # Change 'val_acc' to 'val_accuracy'
    mode='max',
    verbose=1
)


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Remove from_logits=True
    metrics=[
        'accuracy',
        tf.keras.metrics.CategoricalAccuracy(),
    ]
)


history = model.fit(train_generator, epochs=20, validation_data=val_generator, batch_size=batch_size)
# Out:
# Epoch 1/20
# 141/141 [==============================] - 5s 22ms/step - loss: 0.2206 - accuracy: 0.9319 - categorical_accuracy: 0.9319 - val_loss: 0.7889 - val_accuracy: 0.8738 - val_categorical_accuracy: 0.8738
# Epoch 2/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.2002 - accuracy: 0.9393 - categorical_accuracy: 0.9393 - val_loss: 0.8368 - val_accuracy: 0.8810 - val_categorical_accuracy: 0.8810
# Epoch 3/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1884 - accuracy: 0.9457 - categorical_accuracy: 0.9457 - val_loss: 0.8645 - val_accuracy: 0.8800 - val_categorical_accuracy: 0.8800
# Epoch 4/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1848 - accuracy: 0.9429 - categorical_accuracy: 0.9429 - val_loss: 0.8996 - val_accuracy: 0.8800 - val_categorical_accuracy: 0.8800
# Epoch 5/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1738 - accuracy: 0.9456 - categorical_accuracy: 0.9456 - val_loss: 0.8796 - val_accuracy: 0.8831 - val_categorical_accuracy: 0.8831
# Epoch 6/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1556 - accuracy: 0.9529 - categorical_accuracy: 0.9529 - val_loss: 0.8727 - val_accuracy: 0.8872 - val_categorical_accuracy: 0.8872
# Epoch 7/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1442 - accuracy: 0.9547 - categorical_accuracy: 0.9547 - val_loss: 0.8497 - val_accuracy: 0.8774 - val_categorical_accuracy: 0.8774
# Epoch 8/20
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1455 - accuracy: 0.9537 - categorical_accuracy: 0.9537 - val_loss: 0.8959 - val_accuracy: 0.8784 - val_categorical_accuracy: 0.8784
# Epoch 9/20
monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Compile Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', 'categorical_accuracy']
)

# Model Training
history = model.fit(
    train_generator,
    epochs=25,
    validation_data=val_generator,
    batch_size=batch_size,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9645 - categorical_accuracy: 0.9645
# Epoch 1: val_accuracy improved from -inf to 0.88257, saving model to best_model.h7
# 141/141 [==============================] - 8s 43ms/step - loss: 0.1150 - accuracy: 0.9645 - categorical_accuracy: 0.9645 - val_loss: 1.1477 - val_accuracy: 0.8826 - val_categorical_accuracy: 0.8826
# Epoch 2/25
# 138/141 [============================>.] - ETA: 0s - loss: 0.1031 - accuracy: 0.9681 - categorical_accuracy: 0.9681
# Epoch 2: val_accuracy improved from 0.88257 to 0.88567, saving model to best_model.h7
# 141/141 [==============================] - 5s 38ms/step - loss: 0.1035 - accuracy: 0.9679 - categorical_accuracy: 0.9679 - val_loss: 1.1304 - val_accuracy: 0.8857 - val_categorical_accuracy: 0.8857
# Epoch 3/25
# 141/141 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9669 - categorical_accuracy: 0.9669
# Epoch 3: val_accuracy did not improve from 0.88567
# 141/141 [==============================] - 3s 19ms/step - loss: 0.1032 - accuracy: 0.9669 - categorical_accuracy: 0.9669 - val_loss: 1.1580 - val_accuracy: 0.8826 - val_categorical_accuracy: 0.8826
# Epoch 4/25
# 140/141 [============================>.] - ETA: 0s - loss: 0.1096 - accuracy: 0.9642 - categorical_accuracy: 0.9642
# Epoch 4: val_accuracy did not improve from 0.88567
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1100 - accuracy: 0.9641 - categorical_accuracy: 0.9641 - val_loss: 1.0920 - val_accuracy: 0.8826 - val_categorical_accuracy: 0.8826
# Epoch 5/25
# 140/141 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9705 - categorical_accuracy: 0.9705
# Epoch 5: val_accuracy did not improve from 0.88567
# 141/141 [==============================] - 3s 20ms/step - loss: 0.0964 - accuracy: 0.9705 - categorical_accuracy: 0.9705 - val_loss: 1.0387 - val_accuracy: 0.8857 - val_categorical_accuracy: 0.8857
# Epoch 6/25
# 138/141 [============================>.] - ETA: 0s - loss: 0.1053 - accuracy: 0.9655 - categorical_accuracy: 0.9655
# Epoch 6: val_accuracy did not improve from 0.88567
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1052 - accuracy: 0.9652 - categorical_accuracy: 0.9652 - val_loss: 1.0890 - val_accuracy: 0.8800 - val_categorical_accuracy: 0.8800
# Epoch 7/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9686 - categorical_accuracy: 0.9686
# Epoch 7: val_accuracy improved from 0.88567 to 0.88981, saving model to best_model.h7
# 141/141 [==============================] - 6s 40ms/step - loss: 0.0978 - accuracy: 0.9686 - categorical_accuracy: 0.9686 - val_loss: 1.1258 - val_accuracy: 0.8898 - val_categorical_accuracy: 0.8898
# Epoch 8/25
# 140/141 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9674 - categorical_accuracy: 0.9674
# Epoch 8: val_accuracy did not improve from 0.88981
# 141/141 [==============================] - 3s 20ms/step - loss: 0.1027 - accuracy: 0.9674 - categorical_accuracy: 0.9674 - val_loss: 1.0646 - val_accuracy: 0.8789 - val_categorical_accuracy: 0.8789
# Epoch 9/25
# 140/141 [============================>.] - ETA: 0s - loss: 0.0934 - accuracy: 0.9687 - categorical_accuracy: 0.9687
# Epoch 9: val_accuracy did not improve from 0.88981
# 141/141 [==============================] - 3s 20ms/step - loss: 0.0939 - accuracy: 0.9685 - categorical_accuracy: 0.9685 - val_loss: 1.0532 - val_accuracy: 0.8805 - val_categorical_accuracy: 0.8805
# Epoch 10/25
# 138/141 [============================>.] - ETA: 0s - loss: 0.0943 - accuracy: 0.9716 - categorical_accuracy: 0.9716
# Epoch 10: val_accuracy did not improve from 0.88981
# 141/141 [==============================] - 3s 20ms/step - loss: 0.0940 - accuracy: 0.9715 - categorical_accuracy: 0.9715 - val_loss: 1.1621 - val_accuracy: 0.8831 - val_categorical_accuracy: 0.8831

# %%
# Callbacks
checkpoint = ModelCheckpoint('best_model.h8', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

from tensorflow.keras.callbacks import LearningRateScheduler  # Remove the extra character here

def lr_schedule(epoch):
    if epoch < 10:
        return 0.001
    elif 10 <= epoch < 20:
        return 0.0001
    else:
        return 0.00001

lr_scheduler = LearningRateScheduler(lr_schedule)

# Compile Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', 'categorical_accuracy']
)

# Model Training
callbacks = [checkpoint, early_stopping, lr_scheduler]

history = model.fit(
    train_generator,
    epochs=25,
    validation_data=val_generator,
    batch_size=batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/25
# 140/141 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9662 - categorical_accuracy: 0.9662
# Epoch 1: val_accuracy improved from -inf to 0.88464, saving model to best_model.h8
# 141/141 [==============================] - 8s 41ms/step - loss: 0.1045 - accuracy: 0.9662 - categorical_accuracy: 0.9662 - val_loss: 1.0537 - val_accuracy: 0.8846 - val_categorical_accuracy: 0.8846 - lr: 0.0010
# Epoch 2/25
# 138/141 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9701 - categorical_accuracy: 0.9701
# Epoch 2: val_accuracy improved from 0.88464 to 0.88981, saving model to best_model.h8
# 141/141 [==============================] - 6s 41ms/step - loss: 0.0951 - accuracy: 0.9693 - categorical_accuracy: 0.9693 - val_loss: 1.0454 - val_accuracy: 0.8898 - val_categorical_accuracy: 0.8898 - lr: 0.0010
# Epoch 3/25
# 141/141 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9684 - categorical_accuracy: 0.9684
# Epoch 3: val_accuracy did not improve from 0.88981
# 141/141 [==============================] - 3s 20ms/step - loss: 0.0984 - accuracy: 0.9684 - categorical_accuracy: 0.9684 - val_loss: 1.1339 - val_accuracy: 0.8857 - val_categorical_accuracy: 0.8857 - lr: 0.0010
# Epoch 4/25
# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, Dropout

img_shape = (64, 64, 3)
num_classes = 43

# Uncomment here 
Name = "VGG16"
classifier = VGG16(
    include_top=False,
    input_shape=img_shape,
    weights='imagenet'
)

fine_tune_at = 20
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

model = Sequential()
model.add(classifier)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
#model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# ... (previous code)

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_2 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 14991211 (57.19 MB)
# Trainable params: 272171 (1.04 MB)
# Non-trainable params: 14719040 (56.15 MB)
# _________________________________________________________________
# None

# %%
# Callbacks
#checkpoint = ModelCheckpoint('best_model.h8', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_Resnet.h8',
    monitor='val_accuracy',  # Change 'val_acc' to 'val_accuracy'
    mode='max',
    verbose=1
)


model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Remove from_logits=True
    metrics=[
        'accuracy',
        tf.keras.metrics.CategoricalAccuracy(),
    ]
)


history = model.fit(train_generator, epochs=15, validation_data=val_generator, batch_size=batch_size)
# Out:
# Epoch 1/15
# 141/141 [==============================] - 5s 22ms/step - loss: 4.2889 - accuracy: 0.1015 - categorical_accuracy: 0.1015 - val_loss: 3.3996 - val_accuracy: 0.2400 - val_categorical_accuracy: 0.2400
# Epoch 2/15
# 141/141 [==============================] - 3s 20ms/step - loss: 3.2410 - accuracy: 0.2478 - categorical_accuracy: 0.2478 - val_loss: 2.7806 - val_accuracy: 0.3777 - val_categorical_accuracy: 0.3777
# Epoch 3/15
# 141/141 [==============================] - 3s 20ms/step - loss: 2.7443 - accuracy: 0.3413 - categorical_accuracy: 0.3413 - val_loss: 2.3632 - val_accuracy: 0.4868 - val_categorical_accuracy: 0.4868
# Epoch 4/15
# 141/141 [==============================] - 3s 20ms/step - loss: 2.4885 - accuracy: 0.3981 - categorical_accuracy: 0.3981 - val_loss: 2.0987 - val_accuracy: 0.5551 - val_categorical_accuracy: 0.5551
# Epoch 5/15
# 141/141 [==============================] - 3s 20ms/step - loss: 2.2331 - accuracy: 0.4718 - categorical_accuracy: 0.4718 - val_loss: 1.9218 - val_accuracy: 0.5949 - val_categorical_accuracy: 0.5949
# Epoch 6/15
# 141/141 [==============================] - 3s 20ms/step - loss: 2.0510 - accuracy: 0.5111 - categorical_accuracy: 0.5111 - val_loss: 1.7935 - val_accuracy: 0.6322 - val_categorical_accuracy: 0.6322
# Epoch 7/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.9019 - accuracy: 0.5513 - categorical_accuracy: 0.5513 - val_loss: 1.6895 - val_accuracy: 0.6617 - val_categorical_accuracy: 0.6617
# Epoch 8/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.7809 - accuracy: 0.5842 - categorical_accuracy: 0.5842 - val_loss: 1.5955 - val_accuracy: 0.6880 - val_categorical_accuracy: 0.6880
# Epoch 9/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.6690 - accuracy: 0.6107 - categorical_accuracy: 0.6107 - val_loss: 1.5147 - val_accuracy: 0.7118 - val_categorical_accuracy: 0.7118
# Epoch 10/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.5607 - accuracy: 0.6489 - categorical_accuracy: 0.6489 - val_loss: 1.4455 - val_accuracy: 0.7284 - val_categorical_accuracy: 0.7284
# Epoch 11/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.4766 - accuracy: 0.6700 - categorical_accuracy: 0.6700 - val_loss: 1.3826 - val_accuracy: 0.7372 - val_categorical_accuracy: 0.7372
# Epoch 12/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.3909 - accuracy: 0.6878 - categorical_accuracy: 0.6878 - val_loss: 1.3284 - val_accuracy: 0.7512 - val_categorical_accuracy: 0.7512
# Epoch 13/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.3001 - accuracy: 0.7185 - categorical_accuracy: 0.7185 - val_loss: 1.2821 - val_accuracy: 0.7667 - val_categorical_accuracy: 0.7667
# Epoch 14/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.2342 - accuracy: 0.7357 - categorical_accuracy: 0.7357 - val_loss: 1.2332 - val_accuracy: 0.7838 - val_categorical_accuracy: 0.7838
# Epoch 15/15
# 141/141 [==============================] - 3s 20ms/step - loss: 1.1756 - accuracy: 0.7485 - categorical_accuracy: 0.7485 - val_loss: 1.1986 - val_accuracy: 0.7894 - val_categorical_accuracy: 0.7894

# %%
# Callbacks
checkpoint = ModelCheckpoint('best_model.h9', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Compile Model
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy', 'categorical_accuracy']
)

# Model Training
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    batch_size=batch_size,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/20
# 140/141 [============================>.] - ETA: 0s - loss: 1.1243 - accuracy: 0.7671 - categorical_accuracy: 0.7671
# Epoch 1: val_accuracy improved from -inf to 0.80238, saving model to best_model.h9
# 141/141 [==============================] - 8s 41ms/step - loss: 1.1240 - accuracy: 0.7671 - categorical_accuracy: 0.7671 - val_loss: 1.1576 - val_accuracy: 0.8024 - val_categorical_accuracy: 0.8024
# Epoch 2/20
# 138/141 [============================>.] - ETA: 0s - loss: 1.0639 - accuracy: 0.7815 - categorical_accuracy: 0.7815
# Epoch 2: val_accuracy improved from 0.80238 to 0.80341, saving model to best_model.h9
# 141/141 [==============================] - 6s 42ms/step - loss: 1.0627 - accuracy: 0.7820 - categorical_accuracy: 0.7820 - val_loss: 1.1226 - val_accuracy: 0.8034 - val_categorical_accuracy: 0.8034
# Epoch 3/20
# 139/141 [============================>.] - ETA: 0s - loss: 1.0132 - accuracy: 0.7917 - categorical_accuracy: 0.7917
# Epoch 3: val_accuracy improved from 0.80341 to 0.81273, saving model to best_model.h9
# 141/141 [==============================] - 5s 38ms/step - loss: 1.0118 - accuracy: 0.7923 - categorical_accuracy: 0.7923 - val_loss: 1.0899 - val_accuracy: 0.8127 - val_categorical_accuracy: 0.8127
# Epoch 4/20
# 138/141 [============================>.] - ETA: 0s - loss: 0.9652 - accuracy: 0.8060 - categorical_accuracy: 0.8060
# Epoch 4: val_accuracy improved from 0.81273 to 0.82307, saving model to best_model.h9
# 141/141 [==============================] - 5s 39ms/step - loss: 0.9643 - accuracy: 0.8062 - categorical_accuracy: 0.8062 - val_loss: 1.0591 - val_accuracy: 0.8231 - val_categorical_accuracy: 0.8231
# Epoch 5/20
# 139/141 [============================>.] - ETA: 0s - loss: 0.9176 - accuracy: 0.8181 - categorical_accuracy: 0.8181
# Epoch 5: val_accuracy did not improve from 0.82307
# 141/141 [==============================] - 3s 20ms/step - loss: 0.9169 - accuracy: 0.8188 - categorical_accuracy: 0.8188 - val_loss: 1.0369 - val_accuracy: 0.8231 - val_categorical_accuracy: 0.8231
# Epoch 6/20
# 138/141 [============================>.] - ETA: 0s - loss: 0.8698 - accuracy: 0.8333 - categorical_accuracy: 0.8333
# Epoch 6: val_accuracy improved from 0.82307 to 0.83342, saving model to best_model.h9
# 141/141 [==============================] - 6s 42ms/step - loss: 0.8692 - accuracy: 0.8332 - categorical_accuracy: 0.8332 - val_loss: 1.0093 - val_accuracy: 0.8334 - val_categorical_accuracy: 0.8334
# Epoch 7/20
# 140/141 [============================>.] - ETA: 0s - loss: 0.8402 - accuracy: 0.8406 - categorical_accuracy: 0.8406
# Epoch 7: val_accuracy improved from 0.83342 to 0.83859, saving model to best_model.h9
# 141/141 [==============================] - 5s 38ms/step - loss: 0.8415 - accuracy: 0.8404 - categorical_accuracy: 0.8404 - val_loss: 0.9975 - val_accuracy: 0.8386 - val_categorical_accuracy: 0.8386
# Epoch 8/20
# 138/141 [============================>.] - ETA: 0s - loss: 0.8080 - accuracy: 0.8460 - categorical_accuracy: 0.8460
# Epoch 8: val_accuracy did not improve from 0.83859
# 141/141 [==============================] - 3s 20ms/step - loss: 0.8081 - accuracy: 0.8457 - categorical_accuracy: 0.8457 - val_loss: 0.9712 - val_accuracy: 0.8370 - val_categorical_accuracy: 0.8370
# Epoch 9/20
# 140/141 [============================>.] - ETA: 0s - loss: 0.7772 - accuracy: 0.8554 - categorical_accuracy: 0.8554
# Epoch 9: val_accuracy improved from 0.83859 to 0.85153, saving model to best_model.h9
# 141/141 [==============================] - 5s 39ms/step - loss: 0.7773 - accuracy: 0.8556 - categorical_accuracy: 0.8556 - val_loss: 0.9566 - val_accuracy: 0.8515 - val_categorical_accuracy: 0.8515
# Epoch 10/20
# 139/141 [============================>.] - ETA: 0s - loss: 0.7360 - accuracy: 0.8708 - categorical_accuracy: 0.8708
# Epoch 10: val_accuracy did not improve from 0.85153
# Epoch 18/20
# 139/141 [============================>.] - ETA: 0s - loss: 0.5553 - accuracy: 0.9103 - categorical_accuracy: 0.9103
# Epoch 18: val_accuracy improved from 0.86808 to 0.87118, saving model to best_model.h9
# 141/141 [==============================] - 6s 40ms/step - loss: 0.5541 - accuracy: 0.9108 - categorical_accuracy: 0.9108 - val_loss: 0.8611 - val_accuracy: 0.8712 - val_categorical_accuracy: 0.8712
# Epoch 19/20
# 141/141 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.9202 - categorical_accuracy: 0.9202
# Epoch 19: val_accuracy improved from 0.87118 to 0.87222, saving model to best_model.h9
# 141/141 [==============================] - 6s 42ms/step - loss: 0.5302 - accuracy: 0.9202 - categorical_accuracy: 0.9202 - val_loss: 0.8527 - val_accuracy: 0.8722 - val_categorical_accuracy: 0.8722
# Epoch 20/20
# 141/141 [==============================] - ETA: 0s - loss: 0.5198 - accuracy: 0.9220 - categorical_accuracy: 0.9220
# Epoch 20: val_accuracy improved from 0.87222 to 0.87481, saving model to best_model.h9
# 141/141 [==============================] - 5s 39ms/step - loss: 0.5198 - accuracy: 0.9220 - categorical_accuracy: 0.9220 - val_loss: 0.8555 - val_accuracy: 0.8748 - val_categorical_accuracy: 0.8748

# %%
import matplotlib.pyplot as plt

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Assuming you have already built and trained your model
# ...

# Evaluate on the test set
test_results = model.evaluate(test_generator)

test_loss = test_results[0]
test_accuracy = test_results[1]

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 31/31 [==============================] - 1s 23ms/step - loss: 0.9170 - accuracy: 0.8599 - categorical_accuracy: 0.8599
# Test Loss: 0.9170153141021729
# Test Accuracy: 0.8598759174346924

# %%
def load_data_and_labels(directory_path):
    x, y = [], []

    subdirectories = [d for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]

    for class_index, subdir in enumerate(subdirectories):
        class_path = os.path.join(directory_path, subdir)

        for file_name in os.listdir(class_path):
            image_path = os.path.join(class_path, file_name)
            try:
                img = cv2.imread(image_path)
                if img is not None:
                    # Resize image to (32, 32)
                    resized_img = cv2.resize(img, (128, 128))
                    x.append(resized_img)
                    y.append(class_index)
                else:
                    print(f"Error: Unable to read the image {image_path}")
            except Exception as e:
                print(f"Error processing image {image_path}: {str(e)}")

    return np.array(x), np.array(y)

herbdata_path = '/kaggle/input/herb300/train'
x, y = load_data_and_labels(herbdata_path)

# Split the dataset into training, validation, and test sets
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Define ImageDataGenerator instances without augmentation
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators
batch_size = 64
num_classes = len(np.unique(y))
y_train_one_hot = to_categorical(y_train, num_classes=num_classes)
y_val_one_hot = to_categorical(y_val, num_classes=num_classes)
y_test_one_hot = to_categorical(y_test, num_classes=num_classes)

train_generator = train_datagen.flow(x_train, y_train_one_hot, batch_size=batch_size, shuffle=True)
val_generator = val_datagen.flow(x_val, y_val_one_hot, batch_size=batch_size, shuffle=False)
test_generator = test_datagen.flow(x_test, y_test_one_hot, batch_size=batch_size, shuffle=False)
# Out:
# Error: Unable to read the image /kaggle/input/herb300/train/Pongamia_pinnata a/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Alkanet_Root/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Eclipta_Alba/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Excoecaria cochinchinensiss/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Solanum/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lonicera_caprifol/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Prunella_vulgaris/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Beefsteakk/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Gotukola/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Myrica esculentaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/leonarus/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Kamarkas/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Alpinia_Galangaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Holarrhena antidysenterica/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Andrographis paniculata/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Chinese_Yumm/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lochnera_rosea/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Lysimachia/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Ramiee/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Phyllanthuss/desktop.ini
# libpng warning: iTXt: CRC error
# libpng warning: iTXt: CRC error
# Error: Unable to read the image /kaggle/input/herb300/train/Indian Bay Leaf/desktop.ini
# libpng warning: iTXt: CRC error
# Corrupt JPEG data: 5 extraneous bytes before marker 0xee
# Error: Unable to read the image /kaggle/input/herb300/train/Gingerr/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Bearde_ iriss/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Clerodendrum_serratumm/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Oleander/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Tulsii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Goumi_berries/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Oriental/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Artemisia_Argyii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Kumis/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Schefflera heptaphylla/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Rhodomyrtus/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (6).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (5).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (2).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (4).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (3).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/Baseen_albaa (1).avif
# Error: Unable to read the image /kaggle/input/herb300/train/Basella_Albaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Euphorbia/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Tribulus terrestris/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Rehmanniaa/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Parijata/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Eupatorium fortuneii/desktop.ini
# Error: Unable to read the image /kaggle/input/herb300/train/Com_Purslanee/desktop.ini

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, Dropout

img_shape = (128, 128, 3)
num_classes = 43

# Uncomment here 
Name = "VGG16"
classifier = VGG16(
    include_top=False,
    input_shape=img_shape,
    weights='imagenet'
)

#fine_tune_at = 20
for layer in classifier.layers:
    layer.trainable = False

model = Sequential()
model.add(classifier)
model.add(Flatten())
model.add(BatchNormalization())
#model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# ... (previous code)

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  batch_normalization_4 (Bat  (None, 8192)              32768
#  chNormalization)
#
#  dense_4 (Dense)             (None, 128)               1048704
#
#  batch_normalization_5 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 15802219 (60.28 MB)
# Trainable params: 1070891 (4.09 MB)
# Non-trainable params: 14731328 (56.20 MB)
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_Resnet.h1',
    monitor='val_accuracy',  # Change 'val_acc' to 'val_accuracy'
    mode='max',
    verbose=1
)


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Remove from_logits=True
    metrics=[
        'accuracy',
        tf.keras.metrics.CategoricalAccuracy(),
    ]
)


history = model.fit(train_generator, epochs=10, validation_data=val_generator, batch_size=batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 13s 69ms/step - loss: 2.0655 - accuracy: 0.4884 - categorical_accuracy: 0.4884 - val_loss: 1.5399 - val_accuracy: 0.7455 - val_categorical_accuracy: 0.7455
# Epoch 2/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.7100 - accuracy: 0.8271 - categorical_accuracy: 0.8271 - val_loss: 0.8517 - val_accuracy: 0.8551 - val_categorical_accuracy: 0.8551
# Epoch 3/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.3623 - accuracy: 0.9199 - categorical_accuracy: 0.9199 - val_loss: 0.5825 - val_accuracy: 0.8971 - val_categorical_accuracy: 0.8971
# Epoch 4/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2034 - accuracy: 0.9595 - categorical_accuracy: 0.9595 - val_loss: 0.5048 - val_accuracy: 0.9079 - val_categorical_accuracy: 0.9079
# Epoch 5/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.1330 - accuracy: 0.9755 - categorical_accuracy: 0.9755 - val_loss: 0.5069 - val_accuracy: 0.9146 - val_categorical_accuracy: 0.9146
# Epoch 6/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0905 - accuracy: 0.9855 - categorical_accuracy: 0.9855 - val_loss: 0.5307 - val_accuracy: 0.9079 - val_categorical_accuracy: 0.9079
# Epoch 7/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0682 - accuracy: 0.9879 - categorical_accuracy: 0.9879 - val_loss: 0.4993 - val_accuracy: 0.9177 - val_categorical_accuracy: 0.9177
# Epoch 8/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0535 - accuracy: 0.9911 - categorical_accuracy: 0.9911 - val_loss: 0.5304 - val_accuracy: 0.9058 - val_categorical_accuracy: 0.9058
# Epoch 9/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0478 - accuracy: 0.9917 - categorical_accuracy: 0.9917 - val_loss: 0.5456 - val_accuracy: 0.9079 - val_categorical_accuracy: 0.9079
# Epoch 10/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.0366 - accuracy: 0.9946 - categorical_accuracy: 0.9946 - val_loss: 0.5334 - val_accuracy: 0.9115 - val_categorical_accuracy: 0.9115

# %%
import matplotlib.pyplot as plt

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Assuming you have already built and trained your model
# ...

# Evaluate on the test set
test_results = model.evaluate(test_generator)

test_loss = test_results[0]
test_accuracy = test_results[1]

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 31/31 [==============================] - 2s 58ms/step - loss: 0.3288 - accuracy: 0.9173 - categorical_accuracy: 0.9173
# Test Loss: 0.32879042625427246
# Test Accuracy: 0.9172698855400085

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, Dropout

img_shape = (128, 128, 3)
num_classes = 43

# Uncomment here 
Name = "VGG16"
classifier = VGG16(
    include_top=False,
    input_shape=img_shape,
    weights='imagenet'
)

#fine_tune_at = 20
for layer in classifier.layers:
    layer.trainable = False

model = Sequential()
model.add(classifier)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
#model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# ... (previous code)

print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  batch_normalization_6 (Bat  (None, 8192)              32768
#  chNormalization)
#
#  dense_6 (Dense)             (None, 128)               1048704
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 15802219 (60.28 MB)
# Trainable params: 1070891 (4.09 MB)
# Non-trainable params: 14731328 (56.20 MB)
# _________________________________________________________________
# None

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_Resnet.h1',
    monitor='val_accuracy',  # Change 'val_acc' to 'val_accuracy'
    mode='max',
    verbose=1
)


model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Remove from_logits=True
    metrics=[
        'accuracy',
        tf.keras.metrics.CategoricalAccuracy(),
    ]
)


history = model.fit(train_generator, epochs=10, validation_data=val_generator, batch_size=batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 10s 57ms/step - loss: 2.3211 - accuracy: 0.4879 - categorical_accuracy: 0.4879 - val_loss: 1.8842 - val_accuracy: 0.7294 - val_categorical_accuracy: 0.7294
# Epoch 2/10
# 141/141 [==============================] - 8s 55ms/step - loss: 1.0407 - accuracy: 0.8249 - categorical_accuracy: 0.8249 - val_loss: 1.1541 - val_accuracy: 0.8603 - val_categorical_accuracy: 0.8603
# Epoch 3/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.7089 - accuracy: 0.9162 - categorical_accuracy: 0.9162 - val_loss: 0.8465 - val_accuracy: 0.8945 - val_categorical_accuracy: 0.8945
# Epoch 4/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.5522 - accuracy: 0.9528 - categorical_accuracy: 0.9528 - val_loss: 0.7689 - val_accuracy: 0.9136 - val_categorical_accuracy: 0.9136
# Epoch 5/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4867 - accuracy: 0.9670 - categorical_accuracy: 0.9670 - val_loss: 0.7593 - val_accuracy: 0.9089 - val_categorical_accuracy: 0.9089
# Epoch 6/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4491 - accuracy: 0.9730 - categorical_accuracy: 0.9730 - val_loss: 0.7311 - val_accuracy: 0.9157 - val_categorical_accuracy: 0.9157
# Epoch 7/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4411 - accuracy: 0.9693 - categorical_accuracy: 0.9693 - val_loss: 0.7635 - val_accuracy: 0.9058 - val_categorical_accuracy: 0.9058
# Epoch 8/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4827 - accuracy: 0.9605 - categorical_accuracy: 0.9605 - val_loss: 0.7821 - val_accuracy: 0.9038 - val_categorical_accuracy: 0.9038
# Epoch 9/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4958 - accuracy: 0.9629 - categorical_accuracy: 0.9629 - val_loss: 0.8079 - val_accuracy: 0.9121 - val_categorical_accuracy: 0.9121
# Epoch 10/10
# 141/141 [==============================] - 8s 55ms/step - loss: 0.4915 - accuracy: 0.9643 - categorical_accuracy: 0.9643 - val_loss: 0.8203 - val_accuracy: 0.9126 - val_categorical_accuracy: 0.9126

# %%
# Assuming you have already built and trained your model
# ...

# Evaluate on the test set
test_results = model.evaluate(test_generator)

test_loss = test_results[0]
test_accuracy = test_results[1]

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 31/31 [==============================] - 1s 43ms/step - loss: 0.7284 - accuracy: 0.9080 - categorical_accuracy: 0.9080
# Test Loss: 0.7283521890640259
# Test Accuracy: 0.9079627990722656

# %%
import matplotlib.pyplot as plt

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam


# Compile the model with a lower learning rate
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy']
)

# Define callbacks, including early stopping to prevent overfitting
callback_checkpoint = ModelCheckpoint(
    filepath='best_VGG16.h2',
    monitor='val_accuracy',
    mode='max',
    verbose=1,
    save_best_only=True
)

callback_early_stopping = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

# Train the model with callbacks
history = model.fit(
    train_generator,
    epochs=15,
    validation_data=val_generator,
    batch_size=batch_size,
    callbacks=[callback_checkpoint, callback_early_stopping]
)
# Out:
# Epoch 1/15
# 141/141 [==============================] - ETA: 0s - loss: 0.4268 - accuracy: 0.9816
# Epoch 1: val_accuracy improved from -inf to 0.91930, saving model to best_VGG16.h2
# 141/141 [==============================] - 13s 76ms/step - loss: 0.4268 - accuracy: 0.9816 - val_loss: 0.7646 - val_accuracy: 0.9193
# Epoch 2/15
# 141/141 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.9909
# Epoch 2: val_accuracy improved from 0.91930 to 0.92137, saving model to best_VGG16.h2
# 141/141 [==============================] - 10s 74ms/step - loss: 0.3761 - accuracy: 0.9909 - val_loss: 0.7310 - val_accuracy: 0.9214
# Epoch 3/15
# 141/141 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.9936
# Epoch 3: val_accuracy improved from 0.92137 to 0.92292, saving model to best_VGG16.h2
# 141/141 [==============================] - 11s 77ms/step - loss: 0.3504 - accuracy: 0.9936 - val_loss: 0.7064 - val_accuracy: 0.9229
# Epoch 4/15
# 140/141 [============================>.] - ETA: 0s - loss: 0.3290 - accuracy: 0.9949
# Epoch 4: val_accuracy improved from 0.92292 to 0.92344, saving model to best_VGG16.h2
# 141/141 [==============================] - 10s 74ms/step - loss: 0.3289 - accuracy: 0.9949 - val_loss: 0.6933 - val_accuracy: 0.9234
# Epoch 5/15
# 141/141 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.9950
# Epoch 5: val_accuracy did not improve from 0.92344
# 141/141 [==============================] - 8s 55ms/step - loss: 0.3112 - accuracy: 0.9950 - val_loss: 0.6731 - val_accuracy: 0.9229
# Epoch 6/15
# 140/141 [============================>.] - ETA: 0s - loss: 0.2925 - accuracy: 0.9962
# Epoch 6: val_accuracy did not improve from 0.92344
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2924 - accuracy: 0.9962 - val_loss: 0.6701 - val_accuracy: 0.9224
# Epoch 7/15
# 141/141 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9978
# Epoch 7: val_accuracy improved from 0.92344 to 0.92550, saving model to best_VGG16.h2
# 141/141 [==============================] - 11s 75ms/step - loss: 0.2745 - accuracy: 0.9978 - val_loss: 0.6481 - val_accuracy: 0.9255
# Epoch 8/15
# 141/141 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.9978
# Epoch 8: val_accuracy did not improve from 0.92550
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2583 - accuracy: 0.9978 - val_loss: 0.6405 - val_accuracy: 0.9245
# Epoch 9/15
# 140/141 [============================>.] - ETA: 0s - loss: 0.2447 - accuracy: 0.9982
# Epoch 9: val_accuracy did not improve from 0.92550
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2446 - accuracy: 0.9982 - val_loss: 0.6330 - val_accuracy: 0.9250
# Epoch 10/15
# 141/141 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9982
# Epoch 10: val_accuracy did not improve from 0.92550
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2295 - accuracy: 0.9982 - val_loss: 0.6324 - val_accuracy: 0.9250
# Epoch 11/15
# 141/141 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9981
# Epoch 11: val_accuracy did not improve from 0.92550
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2166 - accuracy: 0.9981 - val_loss: 0.6091 - val_accuracy: 0.9245
# Epoch 12/15
# 141/141 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9992
# Epoch 12: val_accuracy did not improve from 0.92550
# Restoring model weights from the end of the best epoch: 7.
# 141/141 [==============================] - 8s 55ms/step - loss: 0.2011 - accuracy: 0.9992 - val_loss: 0.5933 - val_accuracy: 0.9250
# Epoch 12: early stopping

# %%
# Assuming you have already built and trained your model
# ...

# Evaluate on the test set
test_results = model.evaluate(test_generator)

test_loss = test_results[0]
test_accuracy = test_results[1]

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 31/31 [==============================] - 1s 43ms/step - loss: 0.5669 - accuracy: 0.9224
# Test Loss: 0.5668910145759583
# Test Accuracy: 0.9224405288696289

# %%
import matplotlib.pyplot as plt

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
